# %%
#Titanic Data Analysis – Day 2 Exercise
# install Pandas
         # >> pip3 install pandas

# %%
#1-Load dataset, Show first 5 rows

import pandas as pd
df=pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#2-initilize dataset Exploration

# %%
#basic structure and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Summary statics
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Column Name
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#3- Identify missing data

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#4-Data Cleaning

# %%
#Filling missing age with median 
# Syntex
        #df['column'].fillna(value, inplace=True)

df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode())

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex            891
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
## Drop Cabin (too many missing values) (not useful for analysis)
#Syntex
        df.drop(columns=['column1', 'column2'], inplace=True)

df.drop(columns=['Cabin'], inplace=True)
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
## Convert Sex to numeric
# Syntex
        # df['column'] = df['column'].map({'value1': 0, 'value2': 1})

df['Sex']=df['Sex'].map({'female':1,'male':0})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          0 non-null      float64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(3), int64(5), object(4)
# memory usage: 83.7+ KB

# %%
#5- Basic Data Analysis
# Syntex
     # df.groupby('column')['target'].mean()

# Survival rate by gender
print(df.groupby('Sex')['Survived'].mean())
# Out:
# Series([], Name: Survived, dtype: float64)

# %%
#6- Visualization
# install pyplot
        # pip install matplotlib

# Install seaborn, Built on top of Matplotlib, but much easier and better for statistical visualizations.  
        #>> pip3 install seaborn

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Survival count
# Syntex
        # sns.countplot(data=df, x='column', hue='target')

sns.countplot(data=df, x='Survived')
plt.title('Survival Count')
plt.show()

# %%
# Survival by Sex
sns.countplot(data=df,x='Sex', hue='Survived')
plt.title('Survival by Gender')
plt.show()

# %%
# Age distribution by Survived
# Histogram syntex
    # sns.histplot(data=df, x='column', hue='target', kde=True)

sns.histplot(data=df,x='Age',hue='Survived', kde=True)
plt.title('Age Distribution by Survival')
plt.show()

# %%
# Feature Correlation
#Heatmap syntex
        # sns.heatmap(df.corr(), annot=True)

# %%
# Step 1: Check the actual data types
print(df.dtypes)

# Step 2: Force selection of numeric columns safely
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Step 3: Display the numeric columns for verification
print("Numeric Columns Selected:\n", numeric_df.columns)

# Step 4: Generate the heatmap
corr_matrix = numeric_df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation')
plt.show()
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex            float64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object
# Numeric Columns Selected:
#  Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare'],
#       dtype='object')
